# %%
from electrical_data_process import *

# %%
m1 = Measurments('sample_3.1')
p1 = Process_DC_IV(m1.get_abspath())
d1 = Draw_DC_IV(p1, m1)

# %%
#d1.all()

# %%
m1.delete_measurments({'C20-25': [1,2,3,4,5,6,7] + [i for i in range(37,53)]})
C20_25_dict = m1.get_contact_dict('C20-25')

# %%
fig, ax = plt.subplots(figsize = [7, 7])

d1.multiple(C20_25_dict, ax)
ax.set(yscale='log', ylim=(10**(-14), 10**(-4)), xlim= (-1.1, 1.1))
# Out:
# [None, (1e-14, 0.0001), (-1.1, 1.1)]

# %%
I = p1.get_on_off_current(C20_25_dict, 0.2)
np.mean(np.abs(I['I_on_off']))/10**6
# Out:
# 12.771078794528

# %%
from ..scripts.electrical_data_process import Measurments
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from ..scripts.electrical_data_process import Measurments
#
# ImportError: attempted relative import with no known parent package
