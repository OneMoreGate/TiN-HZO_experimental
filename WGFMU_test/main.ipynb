# %%
from classes_V3 import *

# %%
end = pd.read_csv('sample_11.2_6/C3-100/_006.txt', skiprows=4)

# %%
fig, ax = plt.subplots(ncols=1, nrows=1, figsize = [7, 5])

plt.rcParams.update({'font.family':'serif'})

#ax[0].plot(end['Endurance: Time'], end['Voltage'])
ax.plot(end['Endurance: Time']*1e6 - 17526, np.array((end['Current']) * 1e6))

ax.set(ylim=(-2, 12), xlim=[0, 10])
ax.tick_params(labelsize = 13)
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(0.5))
ax.tick_params(axis='x', which = 'major', size = 8, width = 1)
ax.tick_params(axis='x', which = 'minor', size = 4, width = 1)
ax.tick_params(axis='y', which = 'major', size = 6, width = 1)
#ax.set_title('Spike', size = 17)
ax.set_xlabel(r'Time, $\mu  s$', size = 15)
ax.set_ylabel(r'Curent, $\mu  A$', size = 15)
plt.savefig('spike.png', dpi = 300, bbox_inches = 'tight')

# %%
fig, ax = plt.subplots(ncols=1, nrows=1, figsize = [7, 5])

plt.rcParams.update({'font.family':'serif'})

#ax[0].plot(end['Endurance: Time'], end['Voltage'])
ax.plot(end['Endurance: Time']*1e6 - 17526, np.array((end['Current']) * 1e6))

ax.set(ylim=(-2, 12), xlim=[0, 10])
ax.tick_params(labelsize = 13)
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(0.5))
ax.tick_params(axis='x', which = 'major', size = 8, width = 1)
ax.tick_params(axis='x', which = 'minor', size = 4, width = 1)
ax.tick_params(axis='y', which = 'major', size = 6, width = 1)
#ax.set_title('Spike', size = 17)
ax.set_xlabel(r'Time, $\mu  s$', size = 15)
ax.set_ylabel(r'Curent, $\mu  A$', size = 15)
plt.savefig('spike.png', dpi = 300, bbox_inches = 'tight')

# %%
end = end[(end['Endurance: Time'] > 0.01753) & (end['Endurance: Time'] < 0.017533)]
end
# Out:
#        Endurance: Time  Voltage       Current
# 70901         0.017530  2.19883  3.366700e-07
# 70902         0.017530  2.19784  3.777730e-07
# 70903         0.017530  2.19812  3.580320e-06
# 70904         0.017530  2.19897  7.665100e-06
# 70905         0.017531  2.19735  9.707230e-06
# 70906         0.017531  2.19777  1.009570e-05
# 70907         0.017531  2.19826  9.332650e-06
# 70908         0.017531  2.19812  7.839690e-06
# 70909         0.017531  2.19847  6.091730e-06
# 70910         0.017531  2.19798  4.324040e-06
# 70911         0.017531  2.19861  2.701390e-06
# 70912         0.017531  2.19763  1.402820e-06
# 70913         0.017531  2.19777  4.343690e-07
# 70914         0.017531  2.19805 -2.327380e-07
# 70915         0.017531  2.19833 -5.962040e-07
# 70916         0.017532  2.19700 -7.860070e-07
# 70917         0.017532  2.19791 -7.988470e-07
# 70918         0.017532  2.19819 -6.860130e-07
# 70919         0.017532  2.19854 -4.975730e-07
# ...

# %%
np.sum(end['Voltage'] * end['Current'] * (0.017533 - 0.01753) / 29)
# Out:
# 1.4248442502460494e-11
