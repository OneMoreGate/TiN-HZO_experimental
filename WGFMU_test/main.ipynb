# %%
from classes_V3 import *

# %%
end = pd.read_csv('_002.txt', skiprows=4)

# %%
fig, ax = plt.subplots(ncols=1, nrows=2, figsize = [8, 8])

ax[0].plot(end['Endurance: Time'], end['Voltage'])
ax[1].plot(end['Endurance: Time'], np.abs(end['Current']))
#ax[1].set_yscale('log')

# %%
end
# Out:
#      Endurance: Time   Voltage   Current
# 0           0.000012 -0.000609  0.000011
# 1           0.000012 -0.000250  0.000011
# 2           0.000012 -0.000250  0.000010
# 3           0.000012  0.000970  0.000009
# 4           0.000013 -0.000250  0.000011
# ..               ...       ...       ...
# 116         0.000024  0.000611  0.000009
# 117         0.000024  0.000970  0.000010
# 118         0.000024 -0.000107  0.000010
# 119         0.000024  0.000037  0.000011
# 120         0.000024 -0.000035  0.000012
#
# [121 rows x 3 columns]
