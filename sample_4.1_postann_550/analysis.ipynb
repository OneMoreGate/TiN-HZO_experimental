# %%
from classes_V3 import *

# %%
d = DC_IV('sample_4.1')

# %%
#d.draw_all_graphs()

# %%
fig, ax = plt.subplots()
lines = d.draw_multiple_lines('H12-100', ax, color = '#a3a3a3', linewidth = 0.5)
ax.set(yscale='log', title='sample 4.1, H12-100')
# Out:
# [None, Text(0.5, 1.0, 'sample 4.1, H12-100')]

# %%
fig, ax = plt.subplots()
lines = d.draw_multiple_lines('H12-75', ax, color = '#a3a3a3', linewidth = 0.5)
ax.set(yscale='log', title='sample 4.1, H12-75')
# Out:
# [None, Text(0.5, 1.0, 'sample 4.1, H12-75')]

# %%
fig, ax = plt.subplots()
lines = d.draw_multiple_lines('H12-50', ax, color = '#a3a3a3', linewidth = 0.5)
ax.set(yscale='log', title='sample 4.1, H12-50')
# Out:
# [None, Text(0.5, 1.0, 'sample 4.1, H12-50')]

# %%
fig, ax = plt.subplots()
lines = d.draw_multiple_lines('H10-50', ax, color = '#a3a3a3', linewidth = 0.5)
ax.set(yscale='log', title='sample 4.1, H10-50')
# Out:
# [None, Text(0.5, 1.0, 'sample 4.1, H10-50')]

# %%
fig, ax = plt.subplots()
lines = d.draw_multiple_lines('F16-100', ax, color = '#a3a3a3', linewidth = 0.5)
ax.set(yscale='log', title='sample 4.1, F16-100')
# Out:
# [None, Text(0.5, 1.0, 'sample 4.1, F16-100')]

# %%
fig, ax = plt.subplots()
lines = d.draw_multiple_lines('F16-75', ax, color = '#a3a3a3', linewidth = 0.5)
ax.set(yscale='log', title='sample 4.1, F16-75')
# Out:
# [None, Text(0.5, 1.0, 'sample 4.1, F16-75')]

# %%
fig, ax = plt.subplots(figsize = [10, 5])
lines = d.draw_multiple_lines('F16-50', ax, color = '#a3a3a3', linewidth = 0.5)
ax.set(yscale='log', title='sample 4.1, F16-50')
d.colorize_multiple_lines(lines=lines)
cmap = LinearSegmentedColormap.from_list("custom_gradient", ['#ff0000', '#1e00ff'])
cbar = fig.colorbar(cm.ScalarMappable(cmap=cmap), ax=ax)
cbar.set_ticks([0, 1])
cbar.set_ticklabels(['start','end'], size = 15)

# %%
LinearSegmentedColormap.from_list("custom_gradient", ['#ff0000', '#1e00ff'])
