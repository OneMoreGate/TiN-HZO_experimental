# %%
from classes_V3 import *

# %%
d = DC_IV('sample_4.2_s1')

# %%
#d.draw_all_graphs()

# %%
fig, ax = plt.subplots(figsize = [8,5])

d.draw_multiple_lines('C6-100', ax, list(range(140,170)), color = 'k', alpha = 0.5, linewidth = 0.5)
d.draw_multiple_lines('C6-100', ax, list(range(111,140)), color = 'r', alpha = 0.5, linewidth = 0.5)
d.draw_multiple_lines('C6-100', ax, list(range(81,110)), color = 'b', alpha = 0.5, linewidth = 0.5)
d.draw_multiple_lines('C6-100', ax, list(range(50,80)), color = 'c', alpha = 0.5, linewidth = 0.5)
d.draw_multiple_lines('C6-100', ax, list(range(2,32)), color = 'y', alpha = 0.5, linewidth = 0.5)
ax.set_yscale('log')
plt.savefig('multistable_DC.png', dpi = 300, bbox_inches = 'tight')

# %%
fig, ax = plt.subplots(figsize = [8,5])

d.draw_multiple_lines('C6-75', ax, list(range(113,142)), color = 'k', alpha = 0.5, linewidth = 0.5)
d.draw_multiple_lines('C6-75', ax, list(range(93,112)), color = 'r', alpha = 0.5, linewidth = 0.5)
d.draw_multiple_lines('C6-75', ax, list(range(63,92)), color = 'b', alpha = 0.5, linewidth = 0.5)
d.draw_multiple_lines('C6-75', ax, list(range(33,62)), color = 'c', alpha = 0.5, linewidth = 0.5)
d.draw_multiple_lines('C6-75', ax, list(range(2,32)), color = 'y', alpha = 0.5, linewidth = 0.5)
ax.set_yscale('log')
#plt.savefig('multistable_DC.png', dpi = 300, bbox_inches = 'tight')

# %%
on_off_100 = d.get_on_off_current('C6-100', 2)

# %%
plt.scatter(range(len(on_off_100['on'])), on_off_100['on'])
plt.scatter(range(len(on_off_100['off'])), on_off_100['off'])
plt.yscale('log')
plt.ylim([1e-4, 1e-2])
# Out:
# (0.0001, 0.01)

# %%
on_off_75 = d.get_on_off_current('C6-75', 2)

plt.scatter(range(len(on_off_75['on'])), on_off_75['on'])
plt.scatter(range(len(on_off_75['off'])), on_off_75['off'])
plt.yscale('log')
plt.ylim([1e-5, 1e-2])
# Out:
# (1e-05, 0.01)
