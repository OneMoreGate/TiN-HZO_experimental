# %%
from classes_V3 import *
import matplotlib.patches as patches

# %%
d_4_1 = DC_IV('sample_4.1_postann_550_PLD\sample_4.1')
d_4_1_2 = DC_IV('sample_4.1_postann_550_PLD\sample_4.1_2')
d_4_2 = DC_IV('sample_4.2_postann_550_e-beam\sample_4.2')
d_4_2_2 = DC_IV('sample_4.2_postann_550_e-beam\sample_4.2_2')
d_4_3 = DC_IV('sample_4.3_preann_PLD\sample_4.3')
d_4_3_2 = DC_IV('sample_4.3_preann_PLD\sample_4.3_2')
d_4_4 = DC_IV('sample_4.4_preann_e-beam\sample_4.4')
d_6 = DC_IV('sample_6_preann_550_postann_350\sample_6_2')
d_11 = DC_IV('Sample_11.1\sample_11.1_3')

# %%
fig = plt.figure(figsize=(16, 7))
gs = GridSpec(ncols=4, nrows=2, figure=fig)

plt.rcParams.update({'font.family':'Sans Serif'})

ax_1 = fig.add_subplot(gs[0,0])
ax_2 = fig.add_subplot(gs[0,1])
ax_3 = fig.add_subplot(gs[0,2])
ax_4 = fig.add_subplot(gs[1,0])
ax_5 = fig.add_subplot(gs[1,1])
ax_6 = fig.add_subplot(gs[1,2])
ax_7 = fig.add_subplot(gs[0:,3])

y_major = ticker.LogLocator(numticks = 20)
y_minor = ticker.LogLocator(subs = np.arange(1.0, 10.0) * 0.1, numticks = 20)

d_4_1.draw_multiple_lines('F16-75', ax_1, measurs=[i for i in range(1,22)], color = '#a3a3a3', linewidth = 0.5)
d_4_1.draw_single_line('F16-75', ax_1, 20, color = 'k', linewidth = 2)
ax_1.set(yscale='log', ylim=(10**(-14), 10**(-4)), xlim=[-3.25, 3.25])
ax_1.tick_params(labelsize = 15, labelbottom = False)
ax_1.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax_1.xaxis.set_minor_locator(ticker.MultipleLocator(0.25))
ax_1.yaxis.set_major_locator(ticker.FixedLocator([10**-12,10**-10,10**-8,10**-6,10**-4]))
#ax_1.set_yticks([10**-12,10**-10,10**-8,10**-6,10**-4])
ax_1.tick_params(axis='x', direction = 'in', which = 'major', size = 8, width = 1.5)
ax_1.tick_params(axis='x', direction = 'in', which = 'minor', size = 4, width = 1.5)
ax_1.tick_params(axis='y', direction = 'in', which = 'major', size = 6, width = 1.5)
ax_1.set_ylabel('Ag via PLD \n Current, A', size = 17)
ax_1.set_title('PMA', size = 17)
for axis in ['top','bottom','left','right']:
  ax_1.spines[axis].set_linewidth(1.5)

ax_1.text(x=-2.75, y=1e-5, s='1', size = 15,  bbox=dict(facecolor='#4bd027', alpha=0.7, edgecolor='k'))
ax_1.text(x=-2.75, y=5e-7, s='2', size = 15,  bbox=dict(facecolor='#4bd027', alpha=0.7, edgecolor='k'))
ax_1.text(x=-2.75, y=2.5e-8, s='3', size = 15,  bbox=dict(facecolor='#e60303', alpha=0.7, edgecolor='k'))
ax_1.text(x=-2.75, y=1.2e-9, s='4', size = 15,  bbox=dict(facecolor='gray', alpha=0.7, edgecolor='k'))

d_4_3.draw_multiple_lines('C3-100', ax_2, measurs = [i for i in range(35, 55)], color = '#a3a3a3', linewidth = 0.5)
d_4_3.draw_single_line('C3-100', ax_2, 32, color = 'k', linewidth = 2)
ax_2.plot([2.5, 4], [1e-5, 1e-5], color = 'w', linewidth = 5)
ax_2.set(yscale='log', ylim=(10**(-14), 10**(-4)), xlim=[-1.25, 2.75])
ax_2.tick_params(labelsize = 15, labelleft = False, labelbottom = False)
ax_2.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax_2.xaxis.set_minor_locator(ticker.MultipleLocator(0.25))
ax_2.yaxis.set_major_locator(ticker.FixedLocator([10**-14,10**-12,10**-10,10**-8,10**-6,10**-4]))
ax_2.tick_params(axis='x', direction = 'in', which = 'major', size = 8, width = 1.5)
ax_2.tick_params(axis='x', direction = 'in', which = 'minor', size = 4, width = 1.5)
ax_2.tick_params(axis='y', direction = 'in', which = 'major', size = 6, width = 1.5)
ax_2.set_title('PDA', size = 17)
#ax_2.set_xlabel(r'Voltage, $V$', size = 17)
for axis in ['top','bottom','left','right']:
  ax_2.spines[axis].set_linewidth(1.5)

ax_2.text(x=-1, y=1e-5, s='1', size = 15,  bbox=dict(facecolor='#4bd027', alpha=0.7, edgecolor='k'))
ax_2.text(x=-1, y=5e-7, s='2', size = 15,  bbox=dict(facecolor='#e60303', alpha=0.7, edgecolor='k'))
ax_2.text(x=-1, y=2.5e-8, s='3', size = 15,  bbox=dict(facecolor='#4bd027', alpha=0.7, edgecolor='k'))
ax_2.text(x=-1, y=1.2e-9, s='4', size = 15,  bbox=dict(facecolor='#e60303', alpha=0.7, edgecolor='k'))

d_6.draw_multiple_lines('E16-100', ax_3, measurs=[i for i in range(400, 420)], linewidth = 0.5, color = '#a3a3a3')
d_6.draw_single_line('E16-100', ax_3, 422, color = 'k', linewidth = 2)
ax_3.set(yscale='log', ylim=(10**(-14), 10**(-4)), xlim=[-1.25, 1.75])
ax_3.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax_3.xaxis.set_minor_locator(ticker.MultipleLocator(0.25))
ax_3.yaxis.set_major_locator(ticker.FixedLocator([10**-14,10**-12,10**-10,10**-8,10**-6,10**-4]))
ax_3.tick_params(axis='x', direction = 'in', which = 'major', size = 8, width = 1.5)
ax_3.tick_params(axis='x', direction = 'in', which = 'minor', size = 4, width = 1.5)
ax_3.tick_params(axis='y', direction = 'in', which = 'major', size = 6, width = 1.5)
ax_3.tick_params(labelsize = 15, labelleft = False, labelbottom = False)
ax_3.set_title('PDA', size = 17)
for axis in ['top','bottom','left','right']:
  ax_3.spines[axis].set_linewidth(1.5)
ax_3.set_title('PDA + PMA', size = 17)

ax_3.text(x=-1, y=1e-5, s='1', size = 15,  bbox=dict(facecolor='#4bd027', alpha=0.7, edgecolor='k'))
ax_3.text(x=-1, y=5e-7, s='2', size = 15,  bbox=dict(facecolor='#4bd027', alpha=0.7, edgecolor='k'))
ax_3.text(x=-1, y=2.5e-8, s='3', size = 15,  bbox=dict(facecolor='#4bd027', alpha=0.7, edgecolor='k'))
ax_3.text(x=-1, y=1.2e-9, s='4', size = 15,  bbox=dict(facecolor='#4bd027', alpha=0.7, edgecolor='k'))

d_4_2_2.draw_multiple_lines('F10-100', ax_4, measurs=[i for i in range(92,106)], color = '#a3a3a3', linewidth = 1)
d_4_2_2.draw_single_line('F10-100', ax_4, 100, color = 'k', linewidth = 2)
ax_4.set(yscale='log', ylim=(10**(-12), 10**(-2)), xlim=[-3.25, 3.25])
ax_4.tick_params(labelsize = 15)
ax_4.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax_4.xaxis.set_minor_locator(ticker.MultipleLocator(0.25))
ax_4.yaxis.set_major_locator(ticker.FixedLocator([10**-12,10**-10,10**-8,10**-6,10**-4,10**-2]))
ax_4.tick_params(axis='x', direction = 'in', which = 'major', size = 8, width = 1.5)
ax_4.tick_params(axis='x', direction = 'in', which = 'minor', size = 4, width = 1.5)
ax_4.tick_params(axis='y', direction = 'in', which = 'major', size = 6, width = 1.5)
ax_4.set_ylabel('Ag via E-beam \n Current, A', size = 17)
for axis in ['top','bottom','left','right']:
  ax_4.spines[axis].set_linewidth(1.5)
#ax_4.set_title('PMA', size = 17)

ax_4.text(x=-2.75, y=1e-5, s='1', size = 15,  bbox=dict(facecolor='#e60303', alpha=0.7, edgecolor='k'))
ax_4.text(x=-2.75, y=5e-7, s='2', size = 15,  bbox=dict(facecolor='gray', alpha=0.7, edgecolor='k'))
ax_4.text(x=-2.75, y=2.5e-8, s='3', size = 15,  bbox=dict(facecolor='gray', alpha=0.7, edgecolor='k'))
ax_4.text(x=-2.75, y=1.2e-9, s='4', size = 15,  bbox=dict(facecolor='#4bd027', alpha=0.7, edgecolor='k'))

d_4_4.draw_multiple_lines('H7-100', ax_5, measurs = [i for i in range(13,26)], linewidth = 0.5, color = '#a3a3a3')
d_4_4.draw_single_line('H7-100', ax_5, measur=17, color = 'k', linewidth = 2)
ax_5.set(yscale='log', ylim=(10**(-12), 10**(-2)), xlim=[-1.25, 2.75])
ax_5.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax_5.xaxis.set_minor_locator(ticker.MultipleLocator(0.25))
ax_5.tick_params(labelleft = False, labelsize = 15)
ax_5.tick_params(axis='x', direction = 'in', which = 'major', size = 8, width = 1.5)
ax_5.tick_params(axis='x', direction = 'in', which = 'minor', size = 4, width = 1.5)
ax_5.tick_params(axis='y', direction = 'in', which = 'major', size = 6, width = 1.5)
#ax_5.set_title('PDA', size = 17)
for axis in ['top','bottom','left','right']:
  ax_5.spines[axis].set_linewidth(1.5)
ax_5.set_xlabel(r'Voltage, $V$', size = 17)

ax_5.text(x=-1, y=1e-5, s='1', size = 15,  bbox=dict(facecolor='#4bd027', alpha=0.7, edgecolor='k'))
ax_5.text(x=-1, y=5e-7, s='2', size = 15,  bbox=dict(facecolor='#e60303', alpha=0.7, edgecolor='k'))
ax_5.text(x=-1, y=2.5e-8, s='3', size = 15,  bbox=dict(facecolor='#4bd027', alpha=0.7, edgecolor='k'))
ax_5.text(x=-1, y=1.2e-9, s='4', size = 15,  bbox=dict(facecolor='#e60303', alpha=0.7, edgecolor='k'))

d_11.draw_multiple_lines('H11-75', ax_6, measurs = [15,16,17,18,20,22,23,25,29,30,31], linewidth = 0.5, color = '#a3a3a3')
d_11.draw_single_line('H11-75', ax_6, measur=18, color = 'k', linewidth = 2)
ax_6.plot([1.5, 4], [1e-5, 1e-5], color = 'w', linewidth = 5)
ax_6.set(yscale='log', ylim=(10**(-12), 10**(-2)), xlim=[-1.25, 1.75])
ax_6.tick_params(labelleft = False, labelsize = 15)
ax_6.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax_6.xaxis.set_minor_locator(ticker.MultipleLocator(0.25))
ax_6.tick_params(axis='x', direction = 'in', which = 'major', size = 8, width = 1.5)
ax_6.tick_params(axis='x', direction = 'in', which = 'minor', size = 4, width = 1.5)
ax_6.tick_params(axis='y', direction = 'in', which = 'major', size = 6, width = 1.5)
#ax_6.set_title('PDA + PMA', size = 17)
for axis in ['top','bottom','left','right']:
  ax_6.spines[axis].set_linewidth(1.5)

ax_6.text(x=-1, y=1e-5, s='1', size = 15,  bbox=dict(facecolor='#4bd027', alpha=0.7, edgecolor='k'))
ax_6.text(x=-1, y=5e-7, s='2', size = 15,  bbox=dict(facecolor='#4bd027', alpha=0.7, edgecolor='k'))
ax_6.text(x=-1, y=2.5e-8, s='3', size = 15,  bbox=dict(facecolor='#4bd027', alpha=0.7, edgecolor='k'))
ax_6.text(x=-1, y=1.2e-9, s='4', size = 15,  bbox=dict(facecolor='#4bd027', alpha=0.7, edgecolor='k'))

ax_7.tick_params(labelleft = False, labelbottom = False, bottom = False, left = False)
ax_7.axis('off')
ax_7.text(0.1, 0.97, 'Criteria:', size = 17)
ax_7.text(0.1, 0.9, '1. Is threshold switch?', size = 15)
ax_7.text(0.1, 0.85, r'2. Threshold voltage value', size = 15)
ax_7.text(0.1, 0.8, r'3. $I_{on}/I_{off}$ ratio value', size = 15)
ax_7.text(0.1, 0.75, r'4. Switching stability', size = 15)
ax_7.text(0.1, 0.47, 'Grade:', size = 17)
ax_7.text(x=0.1, y=0.4, s='good or yes', size = 15,  bbox=dict(facecolor='#4bd027', alpha=0.7, edgecolor='k'))
ax_7.text(x=0.1, y=0.33, s='medium or not exist', size = 15,  bbox=dict(facecolor='gray', alpha=0.7, edgecolor='k'))
ax_7.text(x=0.1, y=0.26, s='bad or not', size = 15,  bbox=dict(facecolor='#e60303', alpha=0.7, edgecolor='k'))

gs.update(wspace=0, hspace = 0)

#plt.savefig('all_typical_for_article.png', dpi = 300, bbox_inches = 'tight')

# %%
# PMA + PLD

I_off = d_4_1.get_on_off_current('F16-75', 0.5, measurs=[i for i in range(1,22)])['on']
I_on = d_4_1.get_on_off_current('F16-75', 0.5, measurs=[i for i in range(1,22)])['off']
r_off = 0.5 / np.mean(I_off)
V_th = d_4_1.get_ts_on_off_voltage('F16-75', 'p', 0.25)[0]
V_th_mean = np.mean(V_th)
V_th_mean
# Out:
# 0.6855072463768116

# %%
#PMA + PDA + PLD
V_th = d_6.get_ts_on_off_voltage('E16-100', 'p', 0.2)[0]
I = d_6.get_on_off_current('E16-100', 0.2)

# %%
I_on_off = [I['off'][i] / I['on'][i] for i in range(len(I)) if I['on'][i] != 0]
V_th_mean = np.mean(V_th)
V_th_mean, np.mean(I_on_off) / 1e5, 0.2 / np.mean(I_off) / 1e10
# Out:
# (0.4662068965517242, 9.772068198504924, 0.00033814247173188976)

# %%
#PMA + PDA + e-beam
V_th = d_11.get_ts_on_off_voltage('H11-75', 'p', 0.5)[0]
V_th_new = [V_th[i] for i in [15,16,17,18,20,22,23,25,29,30,31]]
V_th_mean = np.mean(V_th_new)
I_off = d_11.get_on_off_current('H11-75', 0.5, [15,16,17,18,20,22,23,25,29,30,31])['on']
I_on = d_11.get_on_off_current('H11-75', 0.5, [15,16,17,18,20,22,23,25,29,30,31])['off']
r_off = 0.5 / np.mean(I_off)
np.mean(I_on / I_off) / 1e5
0.5 / np.mean(I_off) / 1e10
# Out:
# 6.589193618873369

# %%
# PMA + e-beam
I = d_4_2_2.get_on_off_current('F10-100', 1, measurs=[i for i in range(92,106)])
1 / np.mean(I['off']) / 1e4
# Out:
# 4.638587741123026

# %%
# PDA + PLD + e-beam
I = d_4_3.get_on_off_current('C3-100', 0.6, [i for i in range(35, 55)]) # PLD
np.mean(1 / I['on_off']) / 1e5, np.mean(0.6 / I['on']) / 1e9
I = d_4_4.get_on_off_current('H7-100', 0.55, [i for i in range(13,26)]) # e-beam
np.mean(1 / I['on_off']) / 1e5, np.mean(0.55 / I['on']) / 1e9
# Out:
# (2.8510421469921763, 73.11272162404673)

# %%
df = d_4_2_2.get_single_data('F10-100', 92)
plt.scatter(df[0], np.abs(df[1]), s=0.7)
plt.xlim([1e-1, 4])
plt.ylim([1e-7, 1e-2])
plt.xscale('log')
plt.yscale('log')

# %%
from matplotlib import image as mpimg

# %%
fig, ax = plt.subplots(figsize = [7,5])

d_4_2_2.draw_multiple_lines('F10-100', ax, measurs=[i for i in range(92,106)], color = '#a3a3a3', linewidth = 1)
d_4_2_2.draw_single_line('F10-100', ax, 100, color = 'k', linewidth = 2)
ax.set(yscale='log', ylim=(10**(-12), 10**(0)), xlim=[-3.25, 3.25])
ax.tick_params(labelsize = 17)
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(0.25))
ax.yaxis.set_major_locator(ticker.FixedLocator([10**-12,10**-10,10**-8,10**-6,10**-4,10**-2, 1]))
ax.tick_params(axis='x', direction = 'in', which = 'major', size = 8, width = 1.5)
ax.tick_params(axis='x', direction = 'in', which = 'minor', size = 4, width = 1.5)
ax.tick_params(axis='y', direction = 'in', which = 'major', size = 6, width = 1.5)
ax.set_ylabel('Current, A', size = 20)
ax.set_xlabel('Voltage, V', size = 20)
for axis in ['top','bottom','left','right']:
  ax.spines[axis].set_linewidth(1.5)

#plt.savefig('4_2_typical.png', dpi = 300, bbox_inches = 'tight')

# %%
fig, ax = plt.subplots(figsize = [7,5])

d_6.draw_multiple_lines('E16-100', ax, measurs=[i for i in range(400, 440)], linewidth = 1, color = '#a3a3a3')
d_6.draw_single_line('E16-100', ax, 432, color = 'k', linewidth = 3)
ax.set(yscale='log', ylim=(10**(-14), 10**(-4)), xlim=[-1.1, 1.1])
ax.xaxis.set_major_locator(ticker.MultipleLocator(0.5))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(0.1))
ax.yaxis.set_major_locator(ticker.FixedLocator([10**-14,10**-12,10**-10,10**-8,10**-6,10**-4]))
ax.tick_params(axis='x', direction = 'out', which = 'major', size = 8, width = 1.5)
ax.tick_params(axis='x', direction = 'out', which = 'minor', size = 4, width = 1.5)
ax.tick_params(axis='y', direction = 'out', which = 'major', size = 6, width = 1.5)
ax.tick_params(labelsize = 17)
for axis in ['top','bottom','left','right']:
  ax.spines[axis].set_linewidth(1.5)
ax.set_ylabel('Current, A', size = 20)
ax.set_xlabel('Voltage, V', size = 20)
ax.text(-1, 1e-6, 'PDA + PMA \n Ag by PLD', size = 20)

#plt.savefig('6_typical.png', dpi = 300, bbox_inches = 'tight')
