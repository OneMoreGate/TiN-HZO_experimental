# %%
from classes_V3 import *

# %%
d_2 = DC_IV('sample_4.3_2')

# %%
#d_2.draw_all_graphs()

# %%
d = DC_IV('sample_4.3')

# %%
fig, ax = plt.subplots()
d.draw_multiple_lines('C3-100', ax, measurs = [i for i in range(15, 80)], linewidth = 0.5, color = '#a3a3a3')
ax.set_title('sample 4.3, preann, PLD')
ax.set_yscale('log')

# %%
fig, ax = plt.subplots()
#d.draw_multiple_lines('C3-100', ax, measurs = [i for i in range(3, 15)], linewidth = 0.5, color = '#a3a3a3')
d.draw_multiple_lines('G4-100', ax, measurs = [4,5,7,8,9,10,11,19], linewidth = 0.5, color = '#a3a3a3')
ax.set_title('sample 4.3, preann, PLD')
ax.set_yscale('log')
