# %%
from classes_V3 import *

# %%
d = DC_IV('sample_4.3')

# %%
d.delete_measurs('C3-100', [i for i in range(15)])

# %%
fig, ax = plt.subplots()
d.draw_multiple_lines('C3-100', ax, color = '#b1b1b1', linewidth = 0.5)
ax.set_yscale('log')

# %%
plt.hist(d.get_on_off_current('C3-100', 0.5)['on'], bins=10, rwidth=0.8, edgecolor = 'k')
plt.tick_params(labelleft = False, left = False)

# %%
plt.hist(d.get_on_off_current('C3-100', 0.5)['off'], bins=10, rwidth=0.8, edgecolor = 'k')
plt.tick_params(labelleft = False, left = False)

# %%
np.mean(d.get_on_off_current('C3-100', 0.5)['on'])
# Out:
# 2.7584117604058664e-11
